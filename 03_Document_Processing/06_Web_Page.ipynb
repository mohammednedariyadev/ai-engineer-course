# %% [markdown]
# ## 6. Web Scraping Loaders
#
# ### Single Web Page
#
# * **Loader:** `WebBaseLoader`
#
# * **Install:** `pip install beautifulsoup4`
#
# * **Use Case:** Scraping blog posts, documentation pages, or news articles.

# %%
from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader = WebBaseLoader("https://en.wikipedia.org/wiki/Artificial_intelligence")
docs = loader.load()

# %%
print(f"Total Documents: {len(docs)}")
for i, doc in enumerate(docs):
    print(f"\n\nPage No: {i+1}")
    print(f"Source: {doc.metadata.get("source", "None")}")
    print(f"Content: {doc.page_content[10000:10100]}....{doc.page_content[20000:20100]}")
# Out:
# Total Documents: 1
#
#
# Page No: 1
# Source: https://en.wikipedia.org/wiki/Artificial_intelligence
# Content: he step-by-step deduction that early AI research could model. Humans solve most of their problems us....s function (the height).
# Local search uses mathematical optimisation to find a solution to a problem
